# %%
import os

TM_API_KEY = os.environ['TM_API_KEY']

# %% [markdown]
# From the [docs](https://developer.ticketmaster.com/products-and-docs/apis/discovery-api/v2/#search-events-v2)
#
# * The default quota is 5000 API calls per day and rate limitation of 5 requests per second.
# * Deep Paging: we only support retrieving the 1000th item. i.e. ( size * page < 1000)

# %%
latlong = '40.7659051,-111.8487420'  # SLCPython UoU
radius = 60
unit = 'miles'
page = 1
locale = "*"

# %%
url = f"https://app.ticketmaster.com/discovery/v2/venues?apikey={TM_API_KEY}&latlong={latlong}&radius={radius}&unit={unit}&locale={locale}&page={page}"

# %%
import httpx
response = httpx.get(url)
response
# Out:
# <Response [200 OK]>

# %%
response.json()
# Out:
# {'_embedded': {'venues': [{'name': 'Hale Center Theatre at Mountain America',
#     'type': 'venue',
#     'id': 'Z7r9jZa70d',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 13.22,
#     'units': 'MILES',
#     'postalCode': '84070',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Sandy'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '9900 South Monroe Street'},
#     'location': {'longitude': '-111.888397', 'latitude': '40.5769'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'tmr': 467, '_total': 467, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z7r9jZa70d?locale=en-us'}}},
#    {'name': 'Young Living Centre Stage at Hale Centre Theatre',
#     'type': 'venue',
#     'id': 'Z7r9jZaA49',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 13.22,
#     'units': 'MILES',
#     'postalCode': '84070',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Sandy'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '9900 Monroe St'},
#     'location': {'longitude': '-111.888397', 'latitude': '40.5769'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'tmr': 31, '_total': 31, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z7r9jZaA49?locale=en-us'}}},
#    {'name': 'SCERA Center for the Arts',
#     'type': 'venue',
#     'id': 'Z7r9jZa7MW',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 34.79,
#     'units': 'MILES',
#     'postalCode': '84058',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Orem'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '745 S State St'},
#     'location': {'longitude': '-111.717003', 'latitude': '40.2724'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'tmr': 25, '_total': 25, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z7r9jZa7MW?locale=en-us'}}},
#    {'name': 'Jon M Huntsman Center',
#     'type': 'venue',
#     'id': 'KovZpZA1EvFA',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/jon-m-huntsman-center-tickets-salt-lake-city/venue/246507',
#     'locale': 'en-us',
#     'distance': 0.61,
#     'units': 'MILES',
#     'postalCode': '84112',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '1825 East South Campus Drive'},
#     'location': {'longitude': '-111.8395457', 'latitude': '40.7604241'},
#     'markets': [{'name': ' Montana & Idaho"', 'id': '45'}],
#     'dmas': [{'id': 378}],
#     'boxOfficeInfo': {'phoneNumberDetail': '801-581-8849',
#      'openHoursDetail': "The JHC Box Office is only open on event days. Salt Lake 2002 Visitor's Center at Rice Eccles Stadium is also a box office for the Jon M. Huntsman Center. (Same hours, except it is open on Fridays till 10:00pm, and Saturdays 10:00am-10:00pm).",
#      'acceptedPaymentDetail': 'Visa, Mastercard, Discover, American Express, Cash',
#      'willCallDetail': 'Will Call is available at the Box Office. Please make sure to bring your picture I.D. and the credit card that you purchased your tickets with.'},
#     'parkingDetail': 'Various parking lots surround the arena. Facility Fees pay for the parking.',
#     'generalInfo': {'generalRule': 'No cameras, videos, audio. No smoking is allowed inside of the Huntsman Center.',
#      'childRule': 'All ages are allowed. Minimum ticketing requirements for children are dependent on each performance.'},
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/KovZpZA1EvFA?locale=en-us'}}},
#    {'name': 'Salt Lake 2002 Visitors Center',
#     'type': 'venue',
#     'id': 'KovZpZA1lntA',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/salt-lake-2002-visitors-center-tickets-salt-lake-city/venue/246509',
#     'locale': 'en-us',
#     'distance': 0.44,
#     'units': 'MILES',
#     'postalCode': '84112',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '451 South 1400 East'},
#     'location': {'longitude': '-111.850261', 'latitude': '40.7596422'},
#     'markets': [{'name': ' Montana & Idaho"', 'id': '45'}],
#     'dmas': [{'id': 378}],
#     'boxOfficeInfo': {'openHoursDetail': "Monday-Friday 10am-6pm Saturday 10am-10pm Tickets for Rice Eccles Stadium and Jon M. Huntsman Center can also be purchased at the Salt Lake 2002 Visitor's Center Box Office.(For those events they accept Visa, Mastercard, Discover, American Express, Checks and Cash)",
#      'acceptedPaymentDetail': 'Visa or Cash',
#      'willCallDetail': 'Will Call is available at the Box Office. Make sure to bring your picture ID and the credit card you purchased your tickets with.'},
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/KovZpZA1lntA?locale=en-us'}}},
#    {'name': 'Dumke Family Softball Stadium',
#     'type': 'venue',
#     'id': 'KovZ917AiW7',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/dumke-family-softball-stadium-tickets-salt-lake-city/venue/247056',
#     'locale': 'en-us',
#     'distance': 0.45,
#     'units': 'MILES',
#     'postalCode': '84112',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '102 S Wasatch Dr'},
#     'location': {'longitude': '-111.8408016', 'latitude': '40.76837962'},
#     'markets': [{'name': ' Montana & Idaho"', 'id': '45'}],
#     'dmas': [{'id': 229},
#      {'id': 234},
#      {'id': 239},
#      {'id': 284},
#      {'id': 287},
#      {'id': 298},
#      {'id': 302},
#      {'id': 338},
#      {'id': 378},
#      {'id': 404}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/KovZ917AiW7?locale=en-us'}}},
#    {'name': 'Ute Field',
#     'type': 'venue',
#     'id': 'KovZ917ANgH',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/ute-field-tickets-salt-lake-city/venue/246935',
#     'locale': 'en-us',
#     'distance': 0.49,
#     'units': 'MILES',
#     'postalCode': '84112',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '155 Central Campus Dr'},
#     'location': {'longitude': '-111.839459', 'latitude': '40.766528'},
#     'markets': [{'name': ' Montana & Idaho"', 'id': '45'}],
#     'dmas': [{'id': 229},
#      {'id': 234},
#      {'id': 239},
#      {'id': 284},
#      {'id': 287},
#      {'id': 298},
#      {'id': 302},
#      {'id': 338},
#      {'id': 378},
#      {'id': 404}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/KovZ917ANgH?locale=en-us'}}},
#    {'name': 'Rye',
#     'type': 'venue',
#     'id': 'Z7r9jZadVY',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 0.62,
#     'units': 'MILES',
#     'postalCode': '84102',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '239 500 E'},
#     'location': {'longitude': '-111.858597', 'latitude': '40.760899'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z7r9jZadVY?locale=en-us'}}},
#    {'name': 'Red Butte Garden',
#     'type': 'venue',
#     'id': 'KovZpZAdla6A',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/red-butte-garden-tickets-salt-lake-city/venue/246172',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dbimages/RedButte_UT_246172_4Z.gif',
#       'width': 205,
#       'height': 115,
#       'fallback': False}],
#     'distance': 1.12,
#     'units': 'MILES',
#     'postalCode': '84113',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '300 Wakara Way'},
#     'location': {'longitude': '-111.8300613', 'latitude': '40.7580224'},
#     'markets': [{'name': ' Montana & Idaho"', 'id': '45'}],
#     'dmas': [{'id': 378}],
#     'boxOfficeInfo': {'phoneNumberDetail': 'Concert Hotline: 801-587-9939 .',
#      'openHoursDetail': 'Red Butte Visitor Center is for Red Butte Garden Members only. The Box Office is open from 9:00am to 5:00pm, Monday through Saturday.',
#      'acceptedPaymentDetail': 'Red Butte Garden Visitor Center accepts Visa, Mastercard, American Express, Discover, Cash and Checks.',
#      'willCallDetail': 'Located at the Ampitheatre entrance. Will call opens 30 minutes before the gates open. Gates open one and a half hours before show time. *Note: See schedule for show times and scheduled opening of gates.'},
#     'parkingDetail': 'Free parking in and around lower entrance to the garden.',
#     'generalInfo': {'generalRule': 'Low back lawn chairs or blankets only. Picnics and coolers are allowed. No recorders or cameras.',
#      'childRule': 'Discount tickets available for kids ages 3-12. Kids 2 and under enter free.'},
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAdla6A?locale=en-us'}}},
#    {'name': 'Ute Soccer and Lacrosse Field',
#     'type': 'venue',
#     'id': 'Z7r9jZaAun',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 1.19,
#     'units': 'MILES',
#     'postalCode': '84112',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '112 S Wasatch Dr',
#      'line2': 'The University of Utah'},
#     'location': {'longitude': '-111.827904', 'latitude': '40.7729'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z7r9jZaAun?locale=en-us'}}},
#    {'name': 'Marriott Center for Dance Hayes Theatre',
#     'type': 'venue',
#     'id': 'Z7r9jZadTF',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 1.19,
#     'units': 'MILES',
#     'postalCode': '84112',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '330 South 1500 East'},
#     'location': {'longitude': '-111.827904', 'latitude': '40.7729'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z7r9jZadTF?locale=en-us'}}},
#    {'name': 'A. Ray Olpin University Union',
#     'type': 'venue',
#     'id': 'ZFr9jZ6177',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 1.19,
#     'units': 'MILES',
#     'postalCode': '84112',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '200 S. Central Campus Dr.'},
#     'location': {'longitude': '-111.827904', 'latitude': '40.7729'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/ZFr9jZ6177?locale=en-us'}}},
#    {'name': 'Pioneer Theatre Company',
#     'type': 'venue',
#     'id': 'ZFr9jZAaFF',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 1.19,
#     'units': 'MILES',
#     'postalCode': '84112',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '300 South 1400 East'},
#     'location': {'longitude': '-111.827904', 'latitude': '40.7729'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/ZFr9jZAaFF?locale=en-us'}}},
#    {'name': 'Hard Rock Cafe - Salt Lake City',
#     'type': 'venue',
#     'id': 'KovZpZAFnFlA',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/hard-rock-cafe-salt-lake-city-tickets-salt-lake-city/venue/341638',
#     'locale': 'en-us',
#     'distance': 1.42,
#     'units': 'MILES',
#     'postalCode': '84102',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '505 South 600 East', 'line2': '(Trolley Square)'},
#     'location': {'longitude': '-111.8738101', 'latitude': '40.7581638'},
#     'markets': [{'name': ' Montana & Idaho"', 'id': '45'}],
#     'dmas': [{'id': 229},
#      {'id': 239},
#      {'id': 284},
#      {'id': 287},
#      {'id': 298},
#      {'id': 338},
#      {'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAFnFlA?locale=en-us'}}},
#    {'name': 'The Paladium - UT',
#     'type': 'venue',
#     'id': 'ZFr9jZka11',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 1.85,
#     'units': 'MILES',
#     'postalCode': '84103',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '615 N 400 W'},
#     'location': {'longitude': '-111.853302', 'latitude': '40.7924'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/ZFr9jZka11?locale=en-us'}}},
#    {'name': 'Library Square',
#     'type': 'venue',
#     'id': 'KovZ917Ah6X',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/library-square-tickets-salt-lake-city/venue/246881',
#     'locale': 'en-us',
#     'distance': 1.89,
#     'units': 'MILES',
#     'postalCode': '84111',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '400 S and 300 East'},
#     'location': {'longitude': '-111.883952', 'latitude': '40.759655'},
#     'markets': [{'name': ' Montana & Idaho"', 'id': '45'}],
#     'dmas': [{'id': 229},
#      {'id': 234},
#      {'id': 239},
#      {'id': 284},
#      {'id': 287},
#      {'id': 298},
#      {'id': 302},
#      {'id': 338},
#      {'id': 378},
#      {'id': 404}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/KovZ917Ah6X?locale=en-us'}}},
#    {'name': 'Pioneer Park',
#     'type': 'venue',
#     'id': 'ZFr9jZ16Ak',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 1.96,
#     'units': 'MILES',
#     'postalCode': '84139',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '300 S 300 W'},
#     'location': {'longitude': '-111.8862', 'latitude': '40.7668'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/ZFr9jZ16Ak?locale=en-us'}}},
#    {'name': 'The Beehive SLC',
#     'type': 'venue',
#     'id': 'Z7r9jZa7-D',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 1.96,
#     'units': 'MILES',
#     'postalCode': '84111',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '666 S State St'},
#     'location': {'longitude': '-111.883301', 'latitude': '40.754799'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z7r9jZa7-D?locale=en-us'}}},
#    {'name': 'Hangar House',
#     'type': 'venue',
#     'id': 'Z7r9jZa7Le',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 1.96,
#     'units': 'MILES',
#     'postalCode': '84111',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '1016 S State Street'},
#     'location': {'longitude': '-111.883301', 'latitude': '40.754799'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z7r9jZa7Le?locale=en-us'}}},
#    {'name': 'Quarters Arcade Bar - Downtown',
#     'type': 'venue',
#     'id': 'Z7r9jZaAuG',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 1.96,
#     'units': 'MILES',
#     'postalCode': '84111',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Salt Lake City'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '5 E 400 S'},
#     'location': {'longitude': '-111.883301', 'latitude': '40.754799'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'_total': 0, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z7r9jZaAuG?locale=en-us'}}}]},
#  '_links': {'first': {'href': '/discovery/v2/venues?unit=miles&latlong=40.7659051%2C-111.8487420&locale=*&radius=60&page=0&size=20'},
#   'prev': {'href': '/discovery/v2/venues?unit=miles&latlong=40.7659051%2C-111.8487420&locale=*&radius=60&page=0&size=20'},
#   'self': {'href': '/discovery/v2/venues?unit=miles&latlong=40.7659051%2C-111.8487420&page=1&locale=*&radius=60'},
#   'next': {'href': '/discovery/v2/venues?unit=miles&latlong=40.7659051%2C-111.8487420&locale=*&radius=60&page=2&size=20'},
#   'last': {'href': '/discovery/v2/venues?unit=miles&latlong=40.7659051%2C-111.8487420&locale=*&radius=60&page=9&size=20'}},
#  'page': {'size': 20, 'totalElements': 199, 'totalPages': 10, 'number': 1}}

# %%
import pandas as pd

df = pd.DataFrame.from_records(response.json()['_embedded']['venues'])
df
# Out:
#                                                 name   type            id  \
# 0            Hale Center Theatre at Mountain America  venue    Z7r9jZa70d
# 1   Young Living Centre Stage at Hale Centre Theatre  venue    Z7r9jZaA49
# 2                          SCERA Center for the Arts  venue    Z7r9jZa7MW
# 3                              Jon M Huntsman Center  venue  KovZpZA1EvFA
# 4                     Salt Lake 2002 Visitors Center  venue  KovZpZA1lntA
# 5                      Dumke Family Softball Stadium  venue   KovZ917AiW7
# 6                                          Ute Field  venue   KovZ917ANgH
# 7                                                Rye  venue    Z7r9jZadVY
# 8                                   Red Butte Garden  venue  KovZpZAdla6A
# 9                      Ute Soccer and Lacrosse Field  venue    Z7r9jZaAun
# 10           Marriott Center for Dance Hayes Theatre  venue    Z7r9jZadTF
# 11                     A. Ray Olpin University Union  venue    ZFr9jZ6177
# 12                           Pioneer Theatre Company  venue    ZFr9jZAaFF
# 13                   Hard Rock Cafe - Salt Lake City  venue  KovZpZAFnFlA
# 14                                 The Paladium - UT  venue    ZFr9jZka11
# 15                                    Library Square  venue   KovZ917Ah6X
# 16                                      Pioneer Park  venue    ZFr9jZ16Ak
# 17                                   The Beehive SLC  venue    Z7r9jZa7-D
# 18                                      Hangar House  venue    Z7r9jZa7Le
# 19                    Quarters Arcade Bar - Downtown  venue    Z7r9jZaAuG
#
#      test locale  distance  units postalCode        timezone  \
# 0   False  en-us     13.22  MILES      84070  America/Denver
# 1   False  en-us     13.22  MILES      84070  America/Denver
# 2   False  en-us     34.79  MILES      84058  America/Denver
# 3   False  en-us      0.61  MILES      84112  America/Denver
# 4   False  en-us      0.44  MILES      84112  America/Denver
# 5   False  en-us      0.45  MILES      84112  America/Denver
# 6   False  en-us      0.49  MILES      84112  America/Denver
# 7   False  en-us      0.62  MILES      84102  America/Denver
# 8   False  en-us      1.12  MILES      84113  America/Denver
# 9   False  en-us      1.19  MILES      84112  America/Denver
# 10  False  en-us      1.19  MILES      84112  America/Denver
# 11  False  en-us      1.19  MILES      84112  America/Denver
# 12  False  en-us      1.19  MILES      84112  America/Denver
# 13  False  en-us      1.42  MILES      84102  America/Denver
# 14  False  en-us      1.85  MILES      84103  America/Denver
# 15  False  en-us      1.89  MILES      84111  America/Denver
# 16  False  en-us      1.96  MILES      84139  America/Denver
# 17  False  en-us      1.96  MILES      84111  America/Denver
# 18  False  en-us      1.96  MILES      84111  America/Denver
# 19  False  en-us      1.96  MILES      84111  America/Denver
#
#                           city  ...  \
# 0            {'name': 'Sandy'}  ...
# 1            {'name': 'Sandy'}  ...
# 2             {'name': 'Orem'}  ...
# 3   {'name': 'Salt Lake City'}  ...
# 4   {'name': 'Salt Lake City'}  ...
# 5   {'name': 'Salt Lake City'}  ...
# 6   {'name': 'Salt Lake City'}  ...
# 7   {'name': 'Salt Lake City'}  ...
# 8   {'name': 'Salt Lake City'}  ...
# 9   {'name': 'Salt Lake City'}  ...
# 10  {'name': 'Salt Lake City'}  ...
# 11  {'name': 'Salt Lake City'}  ...
# 12  {'name': 'Salt Lake City'}  ...
# 13  {'name': 'Salt Lake City'}  ...
# 14  {'name': 'Salt Lake City'}  ...
# 15  {'name': 'Salt Lake City'}  ...
# 16  {'name': 'Salt Lake City'}  ...
# 17  {'name': 'Salt Lake City'}  ...
# 18  {'name': 'Salt Lake City'}  ...
# 19  {'name': 'Salt Lake City'}  ...
#
#                                              location  \
# 0   {'longitude': '-111.888397', 'latitude': '40.5...
# 1   {'longitude': '-111.888397', 'latitude': '40.5...
# 2   {'longitude': '-111.717003', 'latitude': '40.2...
# 3   {'longitude': '-111.8395457', 'latitude': '40....
# 4   {'longitude': '-111.850261', 'latitude': '40.7...
# 5   {'longitude': '-111.8408016', 'latitude': '40....
# 6   {'longitude': '-111.839459', 'latitude': '40.7...
# 7   {'longitude': '-111.858597', 'latitude': '40.7...
# 8   {'longitude': '-111.8300613', 'latitude': '40....
# 9   {'longitude': '-111.827904', 'latitude': '40.7...
# 10  {'longitude': '-111.827904', 'latitude': '40.7...
# 11  {'longitude': '-111.827904', 'latitude': '40.7...
# 12  {'longitude': '-111.827904', 'latitude': '40.7...
# 13  {'longitude': '-111.8738101', 'latitude': '40....
# 14  {'longitude': '-111.853302', 'latitude': '40.7...
# 15  {'longitude': '-111.883952', 'latitude': '40.7...
# 16  {'longitude': '-111.8862', 'latitude': '40.7668'}
# 17  {'longitude': '-111.883301', 'latitude': '40.7...
# 18  {'longitude': '-111.883301', 'latitude': '40.7...
# 19  {'longitude': '-111.883301', 'latitude': '40.7...
#
#                                                  dmas  \
# 0                                       [{'id': 378}]
# 1                                       [{'id': 378}]
# 2                                       [{'id': 378}]
# 3                                       [{'id': 378}]
# 4                                       [{'id': 378}]
# 5   [{'id': 229}, {'id': 234}, {'id': 239}, {'id':...
# 6   [{'id': 229}, {'id': 234}, {'id': 239}, {'id':...
# 7                                       [{'id': 378}]
# 8                                       [{'id': 378}]
# 9                                       [{'id': 378}]
# 10                                      [{'id': 378}]
# 11                                      [{'id': 378}]
# 12                                      [{'id': 378}]
# 13  [{'id': 229}, {'id': 239}, {'id': 284}, {'id':...
# 14                                      [{'id': 378}]
# 15  [{'id': 229}, {'id': 234}, {'id': 239}, {'id':...
# 16                                      [{'id': 378}]
# 17                                      [{'id': 378}]
# 18                                      [{'id': 378}]
# 19                                      [{'id': 378}]
#
#                                  upcomingEvents  \
# 0   {'tmr': 467, '_total': 467, '_filtered': 0}
# 1     {'tmr': 31, '_total': 31, '_filtered': 0}
# 2     {'tmr': 25, '_total': 25, '_filtered': 0}
# 3                 {'_total': 0, '_filtered': 0}
# 4                 {'_total': 0, '_filtered': 0}
# 5                 {'_total': 0, '_filtered': 0}
# 6                 {'_total': 0, '_filtered': 0}
# 7                 {'_total': 0, '_filtered': 0}
# 8                 {'_total': 0, '_filtered': 0}
# 9                 {'_total': 0, '_filtered': 0}
# 10                {'_total': 0, '_filtered': 0}
# 11                {'_total': 0, '_filtered': 0}
# 12                {'_total': 0, '_filtered': 0}
# 13                {'_total': 0, '_filtered': 0}
# 14                {'_total': 0, '_filtered': 0}
# 15                {'_total': 0, '_filtered': 0}
# 16                {'_total': 0, '_filtered': 0}
# 17                {'_total': 0, '_filtered': 0}
# 18                {'_total': 0, '_filtered': 0}
# 19                {'_total': 0, '_filtered': 0}
#
#                                                _links  \
# 0   {'self': {'href': '/discovery/v2/venues/Z7r9jZ...
# 1   {'self': {'href': '/discovery/v2/venues/Z7r9jZ...
# 2   {'self': {'href': '/discovery/v2/venues/Z7r9jZ...
# 3   {'self': {'href': '/discovery/v2/venues/KovZpZ...
# 4   {'self': {'href': '/discovery/v2/venues/KovZpZ...
# 5   {'self': {'href': '/discovery/v2/venues/KovZ91...
# 6   {'self': {'href': '/discovery/v2/venues/KovZ91...
# 7   {'self': {'href': '/discovery/v2/venues/Z7r9jZ...
# 8   {'self': {'href': '/discovery/v2/venues/KovZpZ...
# 9   {'self': {'href': '/discovery/v2/venues/Z7r9jZ...
# 10  {'self': {'href': '/discovery/v2/venues/Z7r9jZ...
# 11  {'self': {'href': '/discovery/v2/venues/ZFr9jZ...
# 12  {'self': {'href': '/discovery/v2/venues/ZFr9jZ...
# 13  {'self': {'href': '/discovery/v2/venues/KovZpZ...
# 14  {'self': {'href': '/discovery/v2/venues/ZFr9jZ...
# 15  {'self': {'href': '/discovery/v2/venues/KovZ91...
# 16  {'self': {'href': '/discovery/v2/venues/ZFr9jZ...
# 17  {'self': {'href': '/discovery/v2/venues/Z7r9jZ...
# 18  {'self': {'href': '/discovery/v2/venues/Z7r9jZ...
# 19  {'self': {'href': '/discovery/v2/venues/Z7r9jZ...
#
#                                                   url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   https://www.ticketmaster.com/jon-m-huntsman-ce...
# 4   https://www.ticketmaster.com/salt-lake-2002-vi...
# 5   https://www.ticketmaster.com/dumke-family-soft...
# 6   https://www.ticketmaster.com/ute-field-tickets...
# 7                                                 NaN
# 8   https://www.ticketmaster.com/red-butte-garden-...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  https://www.ticketmaster.com/hard-rock-cafe-sa...
# 14                                                NaN
# 15  https://www.ticketmaster.com/library-square-ti...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                         markets  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3   [{'name': ' Montana & Idaho"', 'id': '45'}]
# 4   [{'name': ' Montana & Idaho"', 'id': '45'}]
# 5   [{'name': ' Montana & Idaho"', 'id': '45'}]
# 6   [{'name': ' Montana & Idaho"', 'id': '45'}]
# 7                                           NaN
# 8   [{'name': ' Montana & Idaho"', 'id': '45'}]
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13  [{'name': ' Montana & Idaho"', 'id': '45'}]
# 14                                          NaN
# 15  [{'name': ' Montana & Idaho"', 'id': '45'}]
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
#
#                                         boxOfficeInfo  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   {'phoneNumberDetail': '801-581-8849', 'openHou...
# 4   {'openHoursDetail': 'Monday-Friday 10am-6pm Sa...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   {'phoneNumberDetail': 'Concert Hotline: 801-58...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                         parkingDetail  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Various parking lots surround the arena. Facil...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Free parking in and around lower entrance to t...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                           generalInfo  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   {'generalRule': 'No cameras, videos, audio. No...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   {'generalRule': 'Low back lawn chairs or blank...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                                images
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   [{'ratio': '16_9', 'url': 'https://s1.ticketm....
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 23 columns]

# %%
start_dt = "2025-03-06T15:04:00Z"
url = f"https://app.ticketmaster.com/discovery/v2/events?apikey={TM_API_KEY}&latlong={latlong}&radius={radius}&unit={unit}&locale={locale}&startDateTime={start_dt}"
url
# Out:
# 'https://app.ticketmaster.com/discovery/v2/events?apikey=xNvepKUBCunwA4ppdyAGm2IN2z467vO0&latlong=40.7659051,-111.8487420&radius=60&unit=miles&locale=*&startDateTime=2025-03-06T15:04:00Z'

# %%
resp = httpx.get(url)

# %%
resp
# Out:
# <Response [200 OK]>

# %%
resp.json()
# Out:
# {'_embedded': {'events': [{'name': "POSTPONED: Porno for Pyros - Horns, Thorns En Halo's 2023 Tour",
#     'type': 'event',
#     'id': 'G5vzZ9mbNLM2l',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/postponed-porno-for-pyros-horns-thorns-salt-lake-city-utah-09-27-2025/event/1E005EE6237F73EB',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False},
#      {'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_SOURCE',
#       'width': 2426,
#       'height': 1365,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': False}],
#     'distance': 3.03,
#     'units': 'MILES',
#     'sales': {'public': {'startTBD': False, 'startTBA': False}},
#     'dates': {'start': {'localDate': '2025-09-27',
#       'localTime': '20:00:00',
#       'dateTime': '2025-09-28T02:00:00Z',
#       'dateTBD': False,
#       'dateTBA': False,
#       'timeTBA': False,
#       'noSpecificTime': False},
#      'timezone': 'America/Denver',
#      'status': {'code': 'cancelled'},
#      'spanMultipleDays': False},
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#       'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7v6dt', 'name': 'Alternative Rock'},
#       'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#       'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#       'family': False}],
#     'info': 'POSTPONED. Postfontaine Presents: Porno for Pyros at The Union on October 17th, 2023',
#     'pleaseNote': 'Unfortunately, the Event Organizer has had to cancel your event. No action is required to obtain a refund. It will be processed to the original method of payment used at time of purchase, once funds are received from the Event Organizer, which is usually completed within 30 days. If the Event Organizer is offering a credit option, it will be visible within the Event Details of your order, which can be found in your Ticketmaster account. Please Note: If the tickets were transferred to you, the refund will go to the fan who originally purchased the tickets from Ticketmaster. Please see our Purchase Policy for more information.',
#     'priceRanges': [{'type': 'standard',
#       'currency': 'USD',
#       'min': 55.0,
#       'max': 55.0}],
#     'seatmap': {'staticUrl': 'https://maps.ticketmaster.com/maps/geometry/3/event/1E005EE6237F73EB/staticImage?type=png&systemId=HOST'},
#     'accessibility': {},
#     'ticketLimit': {'info': 'There is an overall 8 ticket limit for this event.'},
#     'ageRestrictions': {'legalAgeEnforced': False},
#     'doorsTimes': {'localDate': '2023-10-17',
#      'localTime': '19:00:00',
#      'dateTime': '2023-10-18T01:00:00Z'},
#     'ticketing': {'safeTix': {'enabled': True},
#      'allInclusivePricing': {'enabled': False}},
#     '_links': {'self': {'href': '/discovery/v2/events/G5vzZ9mbNLM2l?locale=en-us'},
#      'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171FA0?locale=en-us'}],
#      'venues': [{'href': '/discovery/v2/venues/KovZ917A-HC?locale=en-us'}]},
#     '_embedded': {'venues': [{'name': 'The Union',
#        'type': 'venue',
#        'id': 'KovZ917A-HC',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/the-union-tickets-salt-lake-city/venue/246906',
#        'locale': 'en-us',
#        'distance': 3.03,
#        'units': 'MILES',
#        'postalCode': '84116',
#        'timezone': 'America/Denver',
#        'city': {'name': 'Salt Lake City'},
#        'state': {'name': 'Utah', 'stateCode': 'UT'},
#        'country': {'name': 'United States Of America', 'countryCode': 'US'},
#        'address': {'line1': '235 N 500 W'},
#        'location': {'longitude': '-111.905448', 'latitude': '40.774428'},
#        'markets': [{'name': ' Montana & Idaho"', 'id': '45'}],
#        'dmas': [{'id': 229},
#         {'id': 234},
#         {'id': 239},
#         {'id': 284},
#         {'id': 287},
#         {'id': 298},
#         {'id': 302},
#         {'id': 338},
#         {'id': 378},
#         {'id': 404}],
#        'boxOfficeInfo': {'phoneNumberDetail': '(385) 831-7771',
#         'openHoursDetail': 'Our box office is open on event days an hour before doors open until an hour before end of show.',
#         'acceptedPaymentDetail': 'Credit Card or exact cash only.',
#         'willCallDetail': 'Our box office is open on event days an hour before doors open until an hour before end of show.'},
#        'accessibleSeatingDetail': 'Designated ADA section is available to anyone who needs it.',
#        'generalInfo': {'generalRule': 'Venue Policies: - No backpacks or large bags allowed (6 x 8 small bags are okay) - No outside drinks of any kind - No professional cameras of any kind - No laser pointers - No re-entry into the venue after exiting Refund Policy - We have a no refund policy - If an artist has to cancel, reschedule, or modify an event, all ticket holders will receive an email notification with detailed information & options.',
#         'childRule': 'Children age 2 and under are free'},
#        'upcomingEvents': {'ticketmaster': 23, '_total': 23, '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/venues/KovZ917A-HC?locale=en-us'}}}],
#      'attractions': [{'name': 'Porno for Pyros',
#        'type': 'attraction',
#        'id': 'K8vZ9171FA0',
#        'test': False,
#        'url': 'https://www.ticketmaster.com.au/porno-for-pyros-tickets/artist/763399',
#        'locale': 'en-us',
#        'externalLinks': {'wiki': [{'url': 'https://en.wikipedia.org/wiki/Porno_for_Pyros'}],
#         'musicbrainz': [{'id': '211ee5ca-67e3-4845-8313-6e6cbab95b1b'}]},
#        'images': [{'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#          'width': 2048,
#          'height': 1152,
#          'fallback': False},
#         {'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_RETINA_PORTRAIT_16_9.jpg',
#          'width': 640,
#          'height': 360,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_TABLET_LANDSCAPE_16_9.jpg',
#          'width': 1024,
#          'height': 576,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_RETINA_LANDSCAPE_16_9.jpg',
#          'width': 1136,
#          'height': 639,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_ARTIST_PAGE_3_2.jpg',
#          'width': 305,
#          'height': 203,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640,
#          'height': 427,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_EVENT_DETAIL_PAGE_16_9.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_RECOMENDATION_16_9.jpg',
#          'width': 100,
#          'height': 56,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_SOURCE',
#          'width': 2426,
#          'height': 1365,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/37f/1d997e83-74d2-4736-86cb-be634441737f_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
#          'fallback': False}],
#        'classifications': [{'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#          'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7v6dt', 'name': 'Alternative Rock'},
#          'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#          'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#          'family': False}],
#        'upcomingEvents': {'ticketmaster': 4, '_total': 4, '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171FA0?locale=en-us'}}}]}},
#    {'name': 'Queens of the Stone Age - The End is Nero',
#     'type': 'event',
#     'id': 'G5vzZ9i53wMpz',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/queens-of-the-stone-age-the-magna-utah-09-28-2025/event/1E005EC2D2CB75B8',
#     'locale': 'en-us',
#     'images': [{'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_SOURCE',
#       'width': 2426,
#       'height': 1365,
#       'fallback': False}],
#     'distance': 13.81,
#     'units': 'MILES',
#     'sales': {'public': {'startDateTime': '2023-06-09T16:00:00Z',
#       'startTBD': False,
#       'startTBA': False,
#       'endDateTime': '2025-09-29T01:00:00Z'}},
#     'dates': {'start': {'localDate': '2025-09-28',
#       'localTime': '19:00:00',
#       'dateTime': '2025-09-29T01:00:00Z',
#       'dateTBD': False,
#       'dateTBA': False,
#       'timeTBA': False,
#       'noSpecificTime': False},
#      'initialStartDate': {'localDate': '2023-09-30',
#       'localTime': '19:00:00',
#       'dateTime': '2023-10-01T01:00:00Z'},
#      'timezone': 'America/Denver',
#      'status': {'code': 'cancelled'},
#      'spanMultipleDays': False},
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#       'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7v6dt', 'name': 'Alternative Rock'},
#       'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#       'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#       'family': False}],
#     'promoter': {'id': '653',
#      'name': 'LIVE NATION MUSIC',
#      'description': 'LIVE NATION MUSIC / NTL / USA'},
#     'promoters': [{'id': '653',
#       'name': 'LIVE NATION MUSIC',
#       'description': 'LIVE NATION MUSIC / NTL / USA'}],
#     'info': "Due to weather, tonight's show at The Great Saltair Amphitheather has been postponed. Dangerous weather conditions, including high winds, have made it unsafe for concert goers, venue staff, and traveling party. Your safety is of the utmost importance to us, and Queens hope to see you at the rescheduled date. Ticketholders will be contacted directly with further information.",
#     'pleaseNote': 'Unfortunately, the Event Organizer has had to cancel your event. No action is required to obtain a refund. It will be processed to the original method of payment used at time of purchase, once funds are received from the Event Organizer, which is usually completed within 30 days. If the Event Organizer is offering a credit option, it will be visible within the Event Details of your order, which can be found in your Ticketmaster account. Please Note: If the tickets were transferred to you, the refund will go to the fan who originally purchased the tickets from Ticketmaster. Please see our Purchase Policy for more information.',
#     'priceRanges': [{'type': 'standard',
#       'currency': 'USD',
#       'min': 59.5,
#       'max': 59.5}],
#     'seatmap': {'staticUrl': 'https://maps.ticketmaster.com/maps/geometry/3/event/1E005EC2D2CB75B8/staticImage?type=png&systemId=HOST'},
#     'accessibility': {'info': "Due to weather, tonight's show at The Great Saltair Amphitheather has been postponed.\r\nDangerous weather conditions, including high winds, have made it unsafe for concert goers, venue staff, and traveling party. Your safety is of the utmost importance to us, and Queens hope to see you at the rescheduled date.\r\nTicketholders will be contacted directly with further information."},
#     'ticketLimit': {'info': 'There is an overall 8 ticket limit for this event.'},
#     'ageRestrictions': {'legalAgeEnforced': False},
#     'doorsTimes': {'localDate': '2023-09-30',
#      'localTime': '17:30:00',
#      'dateTime': '2023-09-30T23:30:00Z'},
#     'ticketing': {'safeTix': {'enabled': True},
#      'allInclusivePricing': {'enabled': False}},
#     '_links': {'self': {'href': '/discovery/v2/events/G5vzZ9i53wMpz?locale=en-us'},
#      'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171su7?locale=en-us'},
#       {'href': '/discovery/v2/attractions/K8vZ9174rRV?locale=en-us'},
#       {'href': '/discovery/v2/attractions/K8vZ917bmT0?locale=en-us'}],
#      'venues': [{'href': '/discovery/v2/venues/KovZpZAJv6lA?locale=en-us'}]},
#     '_embedded': {'venues': [{'name': 'The Great Saltair',
#        'type': 'venue',
#        'id': 'KovZpZAJv6lA',
#        'test': False,
#        'url': 'https://www.ticketmaster.com/the-great-saltair-tickets-magna/venue/246718',
#        'locale': 'en-us',
#        'distance': 13.81,
#        'units': 'MILES',
#        'postalCode': '84044',
#        'timezone': 'America/Denver',
#        'city': {'name': 'Magna'},
#        'state': {'name': 'Utah', 'stateCode': 'UT'},
#        'country': {'name': 'United States Of America', 'countryCode': 'US'},
#        'address': {'line1': '12408 W Saltair Drive'},
#        'location': {'longitude': '-112.1016088', 'latitude': '40.7091121'},
#        'markets': [{'name': ' Montana & Idaho"', 'id': '45'}],
#        'dmas': [{'id': 229},
#         {'id': 239},
#         {'id': 284},
#         {'id': 287},
#         {'id': 298},
#         {'id': 338},
#         {'id': 378}],
#        'boxOfficeInfo': {'phoneNumberDetail': '(801) 250-6205',
#         'openHoursDetail': 'Our box office is open on event days an hour before doors open until an hour before end of show.',
#         'acceptedPaymentDetail': 'Card or exact cash only',
#         'willCallDetail': 'Our box office is open on event days an hour before doors open until an hour before end of show.'},
#        'accessibleSeatingDetail': 'Designated routes and or areas to make wheelchair access available.',
#        'generalInfo': {'generalRule': 'Refund Policy - We have a no refund policy - If an artist has to cancel, reschedule, or modify an event, all ticket holders will receive an email notification with detailed information & options.'},
#        'upcomingEvents': {'tmr': 1,
#         'ticketmaster': 6,
#         '_total': 7,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/venues/KovZpZAJv6lA?locale=en-us'}}}],
#      'attractions': [{'name': 'Queens of the Stone Age',
#        'type': 'attraction',
#        'id': 'K8vZ9171su7',
#        'test': False,
#        'url': 'https://www.ticketmaster.com.au/queens-of-the-stone-age-tickets/artist/730011',
#        'locale': 'en-us',
#        'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/user/QueensStoneAgeVEVO'}],
#         'twitter': [{'url': 'https://twitter.com/qotsa'}],
#         'itunes': [{'url': 'https://itunes.apple.com/us/artist/id857919'}],
#         'lastfm': [{'url': 'http://www.last.fm/music/Queens+of+the+Stone+Age'}],
#         'facebook': [{'url': 'https://www.facebook.com/QOTSA'}],
#         'wiki': [{'url': 'https://en.wikipedia.org/wiki/Queens_of_the_Stone_Age'}],
#         'musicbrainz': [{'id': '7dc8f5bd-9d0b-4087-9f73-dc164950bbd8'}],
#         'instagram': [{'url': 'https://www.instagram.com/queensofthestoneage/'}],
#         'homepage': [{'url': 'http://www.qotsa.com/'}]},
#        'aliases': ['queen of the stone age',
#         'queens of the stone age',
#         'queens of the stonage',
#         'qotsa'],
#        'images': [{'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_ARTIST_PAGE_3_2.jpg',
#          'width': 305,
#          'height': 203,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_RECOMENDATION_16_9.jpg',
#          'width': 100,
#          'height': 56,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_RETINA_PORTRAIT_16_9.jpg',
#          'width': 640,
#          'height': 360,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_EVENT_DETAIL_PAGE_16_9.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False},
#         {'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#          'width': 2048,
#          'height': 1152,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640,
#          'height': 427,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_TABLET_LANDSCAPE_16_9.jpg',
#          'width': 1024,
#          'height': 576,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_RETINA_LANDSCAPE_16_9.jpg',
#          'width': 1136,
#          'height': 639,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/2b3/de6563cb-e5c7-490f-8a56-1a4d52be02b3_SOURCE',
#          'width': 2426,
#          'height': 1365,
#          'fallback': False}],
#        'classifications': [{'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#          'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7v6dt', 'name': 'Alternative Rock'},
#          'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#          'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#          'family': False}],
#        'upcomingEvents': {'mfx-se': 2,
#         'mfx-es': 3,
#         'mfx-nl': 1,
#         'ticketmaster': 23,
#         'mfx-no': 3,
#         'mfx-de': 1,
#         'mfx-it': 3,
#         '_total': 36,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171su7?locale=en-us'}}},
#       {'name': 'Viagra Boys',
#        'type': 'attraction',
#        'id': 'K8vZ9174rRV',
#        'test': False,
#        'url': 'https://www.ticketmaster.com.au/viagra-boys-tickets/artist/2290931',
#        'locale': 'en-us',
#        'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/channel/UCWEK3RhJB-BkdMZ9fiROVAQ'}],
#         'twitter': [{'url': 'https://twitter.com/viagraboys'}],
#         'itunes': [{'url': 'https://music.apple.com/us/artist/viagra-boys/1073079969'}],
#         'facebook': [{'url': 'https://www.facebook.com/viagraboys/'}],
#         'spotify': [{'url': 'https://open.spotify.com/artist/2nAKP6etu8wXNnezKXgqgg'}],
#         'instagram': [{'url': 'https://www.instagram.com/viagraboys/'}],
#         'homepage': [{'url': 'https://www.vboysstockholm.com/'}]},
#        'images': [{'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_SOURCE',
#          'width': 2100,
#          'height': 1400,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_176121_RETINA_PORTRAIT_16_9.jpg',
#          'width': 640,
#          'height': 360,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_176121_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_176121_EVENT_DETAIL_PAGE_16_9.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_176121_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640,
#          'height': 427,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_176121_RECOMENDATION_16_9.jpg',
#          'width': 100,
#          'height': 56,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_176121_ARTIST_PAGE_3_2.jpg',
#          'width': 305,
#          'height': 203,
#          'fallback': False},
#         {'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_176121_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_176121_RETINA_LANDSCAPE_16_9.jpg',
#          'width': 1136,
#          'height': 639,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_176121_TABLET_LANDSCAPE_16_9.jpg',
#          'width': 1024,
#          'height': 576,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/1df/a5ea202e-8bb1-40c4-bf29-e77a696b71df_176121_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#          'width': 2048,
#          'height': 1152,
#          'fallback': False}],
#        'classifications': [{'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#          'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7v6a6', 'name': 'Punk'},
#          'type': {'id': 'KZAyXgnZfZ7v7l1', 'name': 'Group'},
#          'subType': {'id': 'KZFzBErXgnZfZ7vA71', 'name': 'Band'},
#          'family': False}],
#        'upcomingEvents': {'mfx-se': 1,
#         'ticketmaster': 11,
#         '_total': 12,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9174rRV?locale=en-us'}}},
#       {'name': 'Jehnny Beth',
#        'type': 'attraction',
#        'id': 'K8vZ917bmT0',
#        'test': False,
#        'url': 'https://www.ticketmaster.com.au/jehnny-beth-tickets/artist/2722495',
#        'locale': 'en-us',
#        'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/channel/UCPQmyehM9E47zlKdtfSTvCw'}],
#         'twitter': [{'url': 'https://mobile.twitter.com/jehnbeth'}],
#         'itunes': [{'url': 'https://music.apple.com/us/artist/jehnny-beth/536559896'}],
#         'spotify': [{'url': 'https://open.spotify.com/artist/2WOMBqEsllg2ICn7D2L8ta'}],
#         'facebook': [{'url': 'https://www.facebook.com/jehnnybethofficial'}],
#         'instagram': [{'url': 'https://www.instagram.com/jehnnybeth/'}]},
#        'images': [{'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_1319201_ARTIST_PAGE_3_2.jpg',
#          'width': 305,
#          'height': 203,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_1319201_TABLET_LANDSCAPE_3_2.jpg',
#          'width': 1024,
#          'height': 683,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_1319201_RECOMENDATION_16_9.jpg',
#          'width': 100,
#          'height': 56,
#          'fallback': False},
#         {'ratio': '3_2',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_1319201_RETINA_PORTRAIT_3_2.jpg',
#          'width': 640,
#          'height': 427,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_SOURCE',
#          'width': 2426,
#          'height': 1365,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_1319201_RETINA_PORTRAIT_16_9.jpg',
#          'width': 640,
#          'height': 360,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_1319201_EVENT_DETAIL_PAGE_16_9.jpg',
#          'width': 205,
#          'height': 115,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_1319201_TABLET_LANDSCAPE_16_9.jpg',
#          'width': 1024,
#          'height': 576,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_1319201_RETINA_LANDSCAPE_16_9.jpg',
#          'width': 1136,
#          'height': 639,
#          'fallback': False},
#         {'ratio': '16_9',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_1319201_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#          'width': 2048,
#          'height': 1152,
#          'fallback': False},
#         {'ratio': '4_3',
#          'url': 'https://s1.ticketm.net/dam/a/e66/a93fd4eb-36dd-41eb-8cb7-390bce3bae66_1319201_CUSTOM.jpg',
#          'width': 305,
#          'height': 225,
#          'fallback': False}],
#        'classifications': [{'primary': True,
#          'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#          'genre': {'id': 'KnvZfZ7vAvv', 'name': 'Alternative'},
#          'subGenre': {'id': 'KZazBEonSMnZfZ7vAvJ', 'name': 'Alternative'},
#          'type': {'id': 'KZAyXgnZfZ7v7la', 'name': 'Individual'},
#          'subType': {'id': 'KZFzBErXgnZfZ7vAd7', 'name': 'Musician'},
#          'family': False}],
#        'upcomingEvents': {'mfx-dk': 1,
#         'ticketmaster': 3,
#         '_total': 4,
#         '_filtered': 0},
#        '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ917bmT0?locale=en-us'}}}]}}]},
#  '_links': {'self': {'href': '/discovery/v2/events?unit=miles&startDateTime=2025-03-06T15%3A04%3A00Z&latlong=40.7659051%2C-111.8487420&locale=*&radius=60'}},
#  'page': {'size': 20, 'totalElements': 2, 'totalPages': 1, 'number': 0}}

# %%
df = pd.DataFrame.from_records(resp.json()['_embedded']['events'])
df
# Out:
#                                                 name   type             id  \
# 0  POSTPONED: Porno for Pyros - Horns, Thorns En ...  event  G5vzZ9mbNLM2l
# 1          Queens of the Stone Age - The End is Nero  event  G5vzZ9i53wMpz
#
#     test                                                url locale  \
# 0  False  https://www.ticketmaster.com/postponed-porno-f...  en-us
# 1  False  https://www.ticketmaster.com/queens-of-the-sto...  en-us
#
#                                               images  distance  units  \
# 0  [{'ratio': '16_9', 'url': 'https://s1.ticketm....      3.03  MILES
# 1  [{'ratio': '3_2', 'url': 'https://s1.ticketm.n...     13.81  MILES
#
#                                                sales  ...  \
# 0  {'public': {'startTBD': False, 'startTBA': Fal...  ...
# 1  {'public': {'startDateTime': '2023-06-09T16:00...  ...
#
#                                              seatmap  \
# 0  {'staticUrl': 'https://maps.ticketmaster.com/m...
# 1  {'staticUrl': 'https://maps.ticketmaster.com/m...
#
#                                        accessibility  \
# 0                                                 {}
# 1  {'info': 'Due to weather, tonight's show at Th...
#
#                                          ticketLimit  \
# 0  {'info': 'There is an overall 8 ticket limit f...
# 1  {'info': 'There is an overall 8 ticket limit f...
#
#                ageRestrictions  \
# 0  {'legalAgeEnforced': False}
# 1  {'legalAgeEnforced': False}
#
#                                           doorsTimes  \
# 0  {'localDate': '2023-10-17', 'localTime': '19:0...
# 1  {'localDate': '2023-09-30', 'localTime': '17:3...
#
#                                            ticketing  \
# 0  {'safeTix': {'enabled': True}, 'allInclusivePr...
# 1  {'safeTix': {'enabled': True}, 'allInclusivePr...
#
#                                               _links  \
# 0  {'self': {'href': '/discovery/v2/events/G5vzZ9...
# 1  {'self': {'href': '/discovery/v2/events/G5vzZ9...
#
#                                            _embedded  \
# 0  {'venues': [{'name': 'The Union', 'type': 'ven...
# 1  {'venues': [{'name': 'The Great Saltair', 'typ...
#
#                                             promoter  \
# 0                                                NaN
# 1  {'id': '653', 'name': 'LIVE NATION MUSIC', 'de...
#
#                                            promoters
# 0                                                NaN
# 1  [{'id': '653', 'name': 'LIVE NATION MUSIC', 'd...
#
# [2 rows x 25 columns]
