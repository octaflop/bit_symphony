# %%
# Injected parameters
from dagster import seven as __dm_seven
import dagstermill as __dm_dagstermill
context = __dm_dagstermill._reconstitute_job_context(
    **{
        key: __dm_seven.json.loads(value)
        for key, value
        in {'executable_dict': '{"__class__": "ReconstructablePipeline", "asset_check_selection": {"__frozenset__": []}, "asset_selection": {"__frozenset__": [{"__class__": "AssetKey", "path": ["artists_playground"]}, {"__class__": "AssetKey", "path": ["fetch_concerts"]}]}, "pipeline_name": "__ASSET_JOB", "repository": {"__class__": "ReconstructableRepository", "container_context": null, "container_image": null, "entry_point": ["dagster"], "executable_path": "/Users/faris/workspace/projects/faris/bit_symphony/.venv/bin/python", "pointer": {"__class__": "ModuleCodePointer", "fn_name": "defs", "module": "music", "working_directory": "/Users/faris/workspace/projects/faris/bit_symphony"}, "repository_load_data": null}, "solid_selection_str": null}', 'job_run_dict': '{"__class__": "PipelineRun", "asset_check_selection": {"__frozenset__": []}, "asset_selection": {"__frozenset__": [{"__class__": "AssetKey", "path": ["artists_playground"]}, {"__class__": "AssetKey", "path": ["fetch_concerts"]}]}, "execution_plan_snapshot_id": "81f0bf8ee66b9479a878c0ad53b6c7c7561774eb", "external_pipeline_origin": {"__class__": "ExternalPipelineOrigin", "external_repository_origin": {"__class__": "ExternalRepositoryOrigin", "repository_location_origin": {"__class__": "ManagedGrpcPythonEnvRepositoryLocationOrigin", "loadable_target_origin": {"__class__": "LoadableTargetOrigin", "attribute": null, "executable_path": null, "module_name": "music", "package_name": null, "python_file": null, "working_directory": "/Users/faris/workspace/projects/faris/bit_symphony"}, "location_name": "music"}, "repository_name": "__repository__"}, "pipeline_name": "__ASSET_JOB"}, "has_repository_load_data": false, "mode": null, "parent_run_id": null, "pipeline_code_origin": {"__class__": "PipelinePythonOrigin", "pipeline_name": "__ASSET_JOB", "repository_origin": {"__class__": "RepositoryPythonOrigin", "code_pointer": {"__class__": "ModuleCodePointer", "fn_name": "defs", "module": "music", "working_directory": "/Users/faris/workspace/projects/faris/bit_symphony"}, "container_context": {}, "container_image": null, "entry_point": ["dagster"], "executable_path": "/Users/faris/workspace/projects/faris/bit_symphony/.venv/bin/python"}}, "pipeline_name": "__ASSET_JOB", "pipeline_snapshot_id": "18344653fa36fbd67880ce348a7ea46553e717a0", "root_run_id": null, "run_config": {}, "run_id": "c12492bb-0025-44f9-9171-750b683e3877", "run_op_concurrency": null, "solid_selection": null, "solids_to_execute": null, "status": {"__enum__": "PipelineRunStatus.STARTING"}, "step_keys_to_execute": null, "tags": {".dagster/grpc_info": "{\\"host\\": \\"localhost\\", \\"socket\\": \\"/var/folders/fk/07csw28s7qj2xcz4_f9th0hh0000gn/T/tmp65a_sg16\\"}"}}', 'node_handle_kwargs': '{"name": "artists_playground", "parent": null}', 'instance_ref_dict': '{"__class__": "InstanceRef", "compute_logs_data": {"__class__": "ConfigurableClassData", "class_name": "LocalComputeLogManager", "config_yaml": "base_dir: /Users/faris/workspace/projects/faris/music_dag_home/storage\\n", "module_name": "dagster.core.storage.local_compute_log_manager"}, "custom_instance_class_data": null, "event_storage_data": {"__class__": "ConfigurableClassData", "class_name": "PostgresEventLogStorage", "config_yaml": "postgres_url:\\n  env: PG_CONN_URL\\n", "module_name": "dagster_postgres"}, "local_artifact_storage_data": {"__class__": "ConfigurableClassData", "class_name": "LocalArtifactStorage", "config_yaml": "base_dir: /Users/faris/workspace/projects/faris/music_dag_home\\n", "module_name": "dagster.core.storage.root"}, "run_coordinator_data": {"__class__": "ConfigurableClassData", "class_name": "QueuedRunCoordinator", "config_yaml": "max_concurrent_runs: 5\\n", "module_name": "dagster.core.run_coordinator"}, "run_launcher_data": {"__class__": "ConfigurableClassData", "class_name": "DefaultRunLauncher", "config_yaml": "{}\\n", "module_name": "dagster"}, "run_storage_data": {"__class__": "ConfigurableClassData", "class_name": "PostgresRunStorage", "config_yaml": "postgres_url:\\n  env: PG_CONN_URL\\n", "module_name": "dagster_postgres"}, "schedule_storage_data": {"__class__": "ConfigurableClassData", "class_name": "PostgresScheduleStorage", "config_yaml": "postgres_url:\\n  env: PG_CONN_URL\\n", "module_name": "dagster_postgres"}, "scheduler_data": {"__class__": "ConfigurableClassData", "class_name": "DagsterDaemonScheduler", "config_yaml": "{}\\n", "module_name": "dagster.core.scheduler"}, "secrets_loader_data": null, "settings": {}, "storage_data": {"__class__": "ConfigurableClassData", "class_name": "DagsterPostgresStorage", "config_yaml": "postgres_url:\\n  env: PG_CONN_URL\\n", "module_name": "dagster_postgres"}}', 'step_key': '"artists_playground"', 'output_log_path': '"/var/folders/fk/07csw28s7qj2xcz4_f9th0hh0000gn/T/tmpfqpat9io"', 'marshal_dir': '"/tmp/dagstermill/c12492bb-0025-44f9-9171-750b683e3877/marshal"', 'run_config': '{}'}.items()
    }
)
fetch_concerts = __dm_dagstermill._load_input_parameter('fetch_concerts')
# Out:
# 2024-03-06 18:47:52 -0700 - dagster - DEBUG - __ASSET_JOB - c12492bb-0025-44f9-9171-750b683e3877 - 56482 - RESOURCE_INIT_STARTED - Starting initialization of resources [io_manager, nb_io_manager].
# 2024-03-06 18:47:52 -0700 - dagster - DEBUG - __ASSET_JOB - c12492bb-0025-44f9-9171-750b683e3877 - 56482 - RESOURCE_INIT_SUCCESS - Finished initialization of resources [io_manager, nb_io_manager].
# 2024-03-06 18:47:53 -0700 - dagster - DEBUG - __ASSET_JOB - c12492bb-0025-44f9-9171-750b683e3877 - artists_playground - Loading file from: /Users/faris/workspace/projects/faris/music_dag_home/storage/fetch_concerts using PickledObjectFilesystemIOManager...
# 2024-03-06 18:47:54 -0700 - dagster - DEBUG - __ASSET_JOB - c12492bb-0025-44f9-9171-750b683e3877 - 56482 - artists_playground - ASSET_OBSERVATION - DagsterEventType.ASSET_OBSERVATION for step artists_playground

# %% [markdown]
# # Bit Symphony
# ## A demonstration on an approach to data-orchestration

# %%
import httpx

# %%
import os

# %% [markdown]
# From the [docs](https://developer.ticketmaster.com/products-and-docs/apis/discovery-api/v2/#search-events-v2)
#
# * The default quota is 5000 API calls per day and rate limitation of 5 requests per second.
# * Deep Paging: we only support retrieving the 1000th item. i.e. ( size * page < 1000)

# %%
TM_API_KEY = os.environ['TM_API_KEY']

# %%
latlong = '40.7659051,-111.8487420'  # SLCPython UoU
radius = 60
unit = 'miles'
page = 1
locale = "*"

# %%
url = f"https://app.ticketmaster.com/discovery/v2/venues?apikey={TM_API_KEY}&latlong={latlong}&radius={radius}&unit={unit}&locale={locale}&page={page}"

# %%
response = httpx.get(url)

# %%
response
# Out:
# <Response [200 OK]>

# %%
response.json()
# Out:
# {'_embedded': {'venues': [{'name': 'Hale Center Theatre at Mountain America',
#     'type': 'venue',
#     'id': 'Z7r9jZa70d',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 13.22,
#     'units': 'MILES',
#     'postalCode': '84070',
#     'timezone': 'America/Denver',
#     'city': {'name': 'Sandy'},
#     'state': {'name': 'Utah', 'stateCode': 'UT'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '9900 South Monroe Street'},
#     'location': {'longitude': '-111.888397', 'latitude': '40.5769'},
#     'dmas': [{'id': 378}],
#     'upcomingEvents': {'tmr': 467, '_total': 467, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z7r9jZa70d?locale=en-us'}}},
#    {'name': 'Young Living Centre Stage at Hale Centre Theatre',
#     'type': 'venue',
#     'id': 'Z7r9jZaA49',
#     'test': False,
#     'locale': 'en-us',
#     'distance': 13.22,
#     'units': 'MILES',
#     'postalCode': '84070',
# ...

# %%
import pandas as pd

df = pd.DataFrame.from_records(response.json()['_embedded']['venues'])
df
# Out:
#                                                 name   type            id  \
# 0            Hale Center Theatre at Mountain America  venue    Z7r9jZa70d
# 1   Young Living Centre Stage at Hale Centre Theatre  venue    Z7r9jZaA49
# 2                          SCERA Center for the Arts  venue    Z7r9jZa7MW
# 3                              Jon M Huntsman Center  venue  KovZpZA1EvFA
# 4                     Salt Lake 2002 Visitors Center  venue  KovZpZA1lntA
# 5                      Dumke Family Softball Stadium  venue   KovZ917AiW7
# 6                                          Ute Field  venue   KovZ917ANgH
# 7                                                Rye  venue    Z7r9jZadVY
# 8                                   Red Butte Garden  venue  KovZpZAdla6A
# 9                      Ute Soccer and Lacrosse Field  venue    Z7r9jZaAun
# 10           Marriott Center for Dance Hayes Theatre  venue    Z7r9jZadTF
# 11                     A. Ray Olpin University Union  venue    ZFr9jZ6177
# ...

# %%
start_dt = "2024-03-06T15:04:00Z"
url = f"https://app.ticketmaster.com/discovery/v2/events?apikey={TM_API_KEY}&latlong={latlong}&radius={radius}&unit={unit}&locale={locale}&startDateTime={start_dt}"
url
# Out:
# 'https://app.ticketmaster.com/discovery/v2/events?apikey=xNvepKUBCunwA4ppdyAGm2IN2z467vO0&latlong=40.7659051,-111.8487420&radius=60&unit=miles&locale=*&startDateTime=2024-03-06T15:04:00Z'

# %%
resp = httpx.get(url)

# %%
resp
# Out:
# <Response [200 OK]>

# %%
resp.json()
# Out:
# {'_embedded': {'events': [{'name': 'Utah Jazz vs. Chicago Bulls',
#     'type': 'event',
#     'id': 'Z7r9jZ1AdJ98v',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/event/Z7r9jZ1AdJ98v',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/c81/2e56ca8f-774a-4ad7-b017-81e7292a1c81_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/c81/2e56ca8f-774a-4ad7-b017-81e7292a1c81_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/c81/2e56ca8f-774a-4ad7-b017-81e7292a1c81_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False},
#      {'ratio': '16_9',
# ...

# %%
df = pd.DataFrame.from_records(resp.json()['_embedded']['events'])
df
# Out:
#                             name   type             id   test  \
# 0    Utah Jazz vs. Chicago Bulls  event  Z7r9jZ1AdJ98v  False
# 1   Utah Jazz vs. Boston Celtics  event  Z7r9jZ1AdJ98e  False
# 2                       Hamilton  event  Z7r9jZ1AdO0vI  False
# 3                       Hamilton  event  Z7r9jZ1AdO0vZ  False
# 4                       Hamilton  event  Z7r9jZ1AdO0vE  False
# 5                       Hamilton  event  Z7r9jZ1AdO0ve  False
# 6                       Hamilton  event  Z7r9jZ1AdO0vP  False
# 7                       Hamilton  event  Z7r9jZ1AdO0v-  False
# 8                       Hamilton  event  Z7r9jZ1AdO0ZS  False
# 9                       Hamilton  event  Z7r9jZ1AdO0v4  False
# 10                      Hamilton  event  Z7r9jZ1AdO0vx  False
# 11                      Hamilton  event  Z7r9jZ1AdO0Zg  False
# 12                      Hamilton  event  Z7r9jZ1AdO0v0  False
# 13                      Hamilton  event  Z7r9jZ1AdO0vJ  False
# ...

# %%
import dagstermill as __dm_dagstermill
__dm_dagstermill._teardown()
